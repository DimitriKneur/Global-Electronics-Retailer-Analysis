# %%
import pandas as pd
import datetime
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# ## Read the data and have a snapshot

# %%
# Snapshot of the raw data merged file extracted thanks to the join SQL requests
df = pd.read_csv('d:/Projets/Code/Python/Global-Electronics-Retailer-Analysis/SQL_requests/global-electronics-retailer-analysis-raw-dataset.csv')
df.head()
# Out:
#    StoreKey         StoreState StoreCountry StoreOpenDate  \
# 0         5           Victoria    Australia     12/9/2015
# 1         4           Tasmania    Australia      1/1/2010
# 2         6  Western Australia    Australia      1/1/2010
# 3         6  Western Australia    Australia      1/1/2010
# 4         6  Western Australia    Australia      1/1/2010
#
#    StoreSurfaceAsSquareMeters  Order Number Order Date  ProductKey  \
# 0                        2000       1520023  2/28/2019        1044
# 1                        2000       1120007  1/24/2018        2131
# 2                        2000        370013   1/5/2016           5
# 3                        2000        759002  1/28/2017           8
# 4                        2000        428009   3/3/2016         144
#
#                                 Product Name            Brand  ...  \
# 0             A. Datum SLR Camera X135 Black         A. Datum  ...
# 1   Contoso Coffee Maker Auto 5C E0900 White          Contoso  ...
# 2             Contoso 2G MP3 Player E200 Red          Contoso  ...
# 3          Contoso 4G MP3 Player E400 Silver          Contoso  ...
# 4  Adventure Works 15.6 LCD TV M130W Brown""  Adventure Works  ...
#
#   Currency Code ExchangeVsUSD Quantity CustomerKey    Birthday  Gender  \
# 0           AUD        1.4005        5        1585   8/12/1990  Female
# 1           AUD        1.2395        1        3203   8/18/1998    Male
# 2           AUD        1.3942        2        5097  11/13/1942  Female
# 3           AUD        1.3266        1       10299   5/27/1937    Male
# 4           AUD        1.3624        2       12160    9/5/1956    Male
#
#      CustomerCity    CustomerState CustomerCountry CustomerContinent
# 0      GREEN LAKE         Victoria       Australia         Australia
# 1        ARGENTON  New South Wales       Australia         Australia
# 2  Mount Pleasant       Queensland       Australia         Australia
# 3     BEELBANGERA  New South Wales       Australia         Australia
# 4        Oakhurst  New South Wales       Australia         Australia
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Extract the main information about the dataframe

# %%
# Number of rows and columns
df.shape
# Out:
# (62884, 24)

# %%
# Column list
df.keys()
# Out:
# Index(['StoreKey', 'StoreState', 'StoreCountry', 'StoreOpenDate',
#        'StoreSurfaceAsSquareMeters', 'Order Number', 'Order Date',
#        'ProductKey', 'Product Name', 'Brand', 'Category', 'Subcategory',
#        'Unit Cost USD', 'Unit Price USD', 'Currency Code', 'ExchangeVsUSD',
#        'Quantity', 'CustomerKey', 'Birthday', 'Gender', 'CustomerCity',
#        'CustomerState', 'CustomerCountry', 'CustomerContinent'],
#       dtype='object')

# %%
# Are there missing values ?
df.isnull().any()
# Out:
# StoreKey                      False
# StoreState                    False
# StoreCountry                  False
# StoreOpenDate                 False
# StoreSurfaceAsSquareMeters    False
# Order Number                  False
# Order Date                    False
# ProductKey                    False
# Product Name                  False
# Brand                         False
# Category                      False
# Subcategory                   False
# Unit Cost USD                 False
# Unit Price USD                False
# Currency Code                 False
# ExchangeVsUSD                 False
# Quantity                      False
# CustomerKey                   False
# Birthday                      False
# Gender                        False
# CustomerCity                  False
# CustomerState                 False
# CustomerCountry               False
# CustomerContinent             False
# dtype: bool

# %%
# Main metrics of the dataset
df.describe(include='all')
# Out:
#             StoreKey StoreState   StoreCountry StoreOpenDate  \
# count   62884.000000      62884          62884         62884
# unique           NaN         58              9            24
# top              NaN     Online  United States      1/1/2000
# freq             NaN      13165          26555         13165
# mean       31.802144        NaN            NaN           NaN
# std        22.978188        NaN            NaN           NaN
# min         0.000000        NaN            NaN           NaN
# 25%         8.000000        NaN            NaN           NaN
# 50%        37.000000        NaN            NaN           NaN
# 75%        53.000000        NaN            NaN           NaN
# max        66.000000        NaN            NaN           NaN
#
#         StoreSurfaceAsSquareMeters  Order Number  Order Date    ProductKey  \
# count                 62884.000000  6.288400e+04       62884  62884.000000
# unique                         NaN           NaN        1641           NaN
# top                            NaN           NaN  12/21/2019           NaN
# freq                           NaN           NaN         222           NaN
# mean                   1260.640306  1.430905e+06         NaN   1125.859344
# std                     767.739494  4.532963e+05         NaN    709.244010
# min                       0.000000  3.660000e+05         NaN      1.000000
# 25%                     840.000000  1.121017e+06         NaN    437.000000
# 50%                    1330.000000  1.498016e+06         NaN   1358.000000
# 75%                    2000.000000  1.788010e+06         NaN   1650.000000
# max                    2105.000000  2.243032e+06         NaN   2517.000000
#
#                                       Product Name    Brand  ...  \
# count                                        62884    62884  ...
# unique                                        2492       11  ...
# top     Adventure Works Desktop PC2.30 MD230 Black  Contoso  ...
# freq                                           162    15953  ...
# mean                                           NaN      NaN  ...
# std                                            NaN      NaN  ...
# min                                            NaN      NaN  ...
# 25%                                            NaN      NaN  ...
# 50%                                            NaN      NaN  ...
# 75%                                            NaN      NaN  ...
# max                                            NaN      NaN  ...
#
#        Currency Code ExchangeVsUSD      Quantity   CustomerKey  Birthday  \
# count          62884  62884.000000  62884.000000  6.288400e+04     62884
# unique             5           NaN           NaN           NaN      9382
# top              USD           NaN           NaN           NaN  5/5/1950
# freq           33767           NaN           NaN           NaN        44
# mean             NaN      0.992533      3.144790  1.180797e+06       NaN
# std              NaN      0.161601      2.256371  5.859634e+05       NaN
# min              NaN      0.672500      1.000000  3.010000e+02       NaN
# 25%              NaN      0.894500      1.000000  6.808580e+05       NaN
# 50%              NaN      1.000000      2.000000  1.261200e+06       NaN
# 75%              NaN      1.000000      4.000000  1.686496e+06       NaN
# max              NaN      1.665200     10.000000  2.099937e+06       NaN
#
#         Gender  CustomerCity  CustomerState CustomerCountry CustomerContinent
# count    62884         62884          62884           62884             62884
# unique       2          6570            491               8                 3
# top       Male       Toronto     California   United States     North America
# freq     31804           683           3629           33767             39182
# mean       NaN           NaN            NaN             NaN               NaN
# std        NaN           NaN            NaN             NaN               NaN
# min        NaN           NaN            NaN             NaN               NaN
# 25%        NaN           NaN            NaN             NaN               NaN
# 50%        NaN           NaN            NaN             NaN               NaN
# 75%        NaN           NaN            NaN             NaN               NaN
# max        NaN           NaN            NaN             NaN               NaN
#
# [11 rows x 24 columns]

# %%
# What is the type of each column of the dataframe ?
df.dtypes
# Out:
# StoreKey                        int64
# StoreState                     object
# StoreCountry                   object
# StoreOpenDate                  object
# StoreSurfaceAsSquareMeters      int64
# Order Number                    int64
# Order Date                     object
# ProductKey                      int64
# Product Name                   object
# Brand                          object
# Category                       object
# Subcategory                    object
# Unit Cost USD                  object
# Unit Price USD                 object
# Currency Code                  object
# ExchangeVsUSD                 float64
# Quantity                        int64
# CustomerKey                     int64
# Birthday                       object
# Gender                         object
# CustomerCity                   object
# CustomerState                  object
# CustomerCountry                object
# CustomerContinent              object
# dtype: object

# %% [markdown]
# ## Data Cleaning

# %%
# StoreKey, OrderNumber, ProductKey and CustomerKey are IDs,
# no need to make operations on it, so let's transform theù into string columns
df["StoreKey"] = df["StoreKey"].apply(lambda x : str(x))
df["Order Number"] = df["Order Number"].apply(lambda x : str(x))
df["ProductKey"] = df["ProductKey"].apply(lambda x : str(x))
df["CustomerKey"] = df["CustomerKey"].apply(lambda x : str(x))
df.dtypes
# Out:
# StoreKey                       object
# StoreState                     object
# StoreCountry                   object
# StoreOpenDate                  object
# StoreSurfaceAsSquareMeters      int64
# Order Number                   object
# Order Date                     object
# ProductKey                     object
# Product Name                   object
# Brand                          object
# Category                       object
# Subcategory                    object
# Unit Cost USD                  object
# Unit Price USD                 object
# Currency Code                  object
# ExchangeVsUSD                 float64
# Quantity                        int64
# CustomerKey                    object
# Birthday                       object
# Gender                         object
# CustomerCity                   object
# CustomerState                  object
# CustomerCountry                object
# CustomerContinent              object
# dtype: object

# %%
# Conversion of all element of the StoreOpenDate, Order Date and Birthday columns from string into date object
df["StoreOpenDate"] = df["StoreOpenDate"].apply(lambda x : pd.to_datetime(x, format="%m/%d/%Y").date())
df["Order Date"] = df["Order Date"].apply(lambda x : pd.to_datetime(x, format="%m/%d/%Y").date())
df["Birthday"] = df["Birthday"].apply(lambda x : pd.to_datetime(x, format="%m/%d/%Y").date())
df
# Out:
#       StoreKey         StoreState   StoreCountry StoreOpenDate  \
# 0            5           Victoria      Australia    2015-12-09
# 1            4           Tasmania      Australia    2010-01-01
# 2            6  Western Australia      Australia    2010-01-01
# 3            6  Western Australia      Australia    2010-01-01
# 4            6  Western Australia      Australia    2010-01-01
# ...        ...                ...            ...           ...
# 62879       50             Kansas  United States    2008-03-06
# 62880       53            Montana  United States    2012-06-06
# 62881       53            Montana  United States    2012-06-06
# 62882       53            Montana  United States    2012-06-06
# 62883       53            Montana  United States    2012-06-06
#
#        StoreSurfaceAsSquareMeters Order Number  Order Date ProductKey  \
# 0                            2000      1520023  2019-02-28       1044
# 1                            2000      1120007  2018-01-24       2131
# 2                            2000       370013  2016-01-05          5
# 3                            2000       759002  2017-01-28          8
# 4                            2000       428009  2016-03-03        144
# ...                           ...          ...         ...        ...
# 62879                        2000      1715000  2019-09-11       1470
# 62880                        1260      1428025  2018-11-28       1644
# 62881                        1260      1428025  2018-11-28       2109
# 62882                        1260      1428025  2018-11-28       1621
# 62883                        1260      1428025  2018-11-28        721
#
#                                             Product Name              Brand  \
# 0                         A. Datum SLR Camera X135 Black           A. Datum
# 1               Contoso Coffee Maker Auto 5C E0900 White            Contoso
# 2                         Contoso 2G MP3 Player E200 Red            Contoso
# 3                      Contoso 4G MP3 Player E400 Silver            Contoso
# 4              Adventure Works 15.6 LCD TV M130W Brown""    Adventure Works
# ...                                                  ...                ...
# 62879  The Phone Company Smart phones without camera ...  The Phone Company
# 62880          Contoso DVD External DVD Burner M200 Blue            Contoso
# 62881             Contoso Water Heater 1.5GPM E0800 Grey            Contoso
# 62882                     Contoso DVD Movies E100 Yellow            Contoso
# 62883  Proseware High-Performance Business-Class Lase...          Proseware
#
#        ... Currency Code ExchangeVsUSD Quantity CustomerKey    Birthday  \
# 0      ...           AUD        1.4005        5        1585  1990-08-12
# 1      ...           AUD        1.2395        1        3203  1998-08-18
# 2      ...           AUD        1.3942        2        5097  1942-11-13
# 3      ...           AUD        1.3266        1       10299  1937-05-27
# 4      ...           AUD        1.3624        2       12160  1956-09-05
# ...    ...           ...           ...      ...         ...         ...
# 62879  ...           USD        1.0000        1     2051398  1979-04-15
# 62880  ...           USD        1.0000        6     2068819  1977-08-19
# 62881  ...           USD        1.0000        1     2068819  1977-08-19
# 62882  ...           USD        1.0000        4     2068819  1977-08-19
# 62883  ...           USD        1.0000       10     2068819  1977-08-19
#
#        Gender     CustomerCity    CustomerState CustomerCountry  \
# 0      Female       GREEN LAKE         Victoria       Australia
# 1        Male         ARGENTON  New South Wales       Australia
# 2      Female   Mount Pleasant       Queensland       Australia
# 3        Male      BEELBANGERA  New South Wales       Australia
# 4        Male         Oakhurst  New South Wales       Australia
# ...       ...              ...              ...             ...
# 62879    Male  Fort Washington     Pennsylvania   United States
# 62880  Female            Utica         New York   United States
# 62881  Female            Utica         New York   United States
# 62882  Female            Utica         New York   United States
# 62883  Female            Utica         New York   United States
#
#       CustomerContinent
# 0             Australia
# 1             Australia
# 2             Australia
# 3             Australia
# 4             Australia
# ...                 ...
# 62879     North America
# 62880     North America
# 62881     North America
# 62882     North America
# 62883     North America
#
# [62884 rows x 24 columns]

# %%
# Define a function to remove the '$' symbol and the comma separating thousands
def remove_dollar_sign(value):
    return float(value.replace("$", "").replace(",", ""))

# Apply the function to the “Unit Cost USD” column with apply
df["Unit Cost USD"] = df["Unit Cost USD"].apply(remove_dollar_sign)
df["Unit Price USD"] = df["Unit Price USD"].apply(remove_dollar_sign)

# Show updated columns
df[["Unit Cost USD", "Unit Price USD"]]
# Out:
#        Unit Cost USD  Unit Price USD
# 0             207.74          627.00
# 1              83.10          163.00
# 2              11.00           21.57
# 3              30.58           59.99
# 4             152.94          299.99
# ...              ...             ...
# 62879          65.77          129.00
# 62880          26.62           57.88
# 62881         131.28          257.50
# 62882           6.62           12.99
# 62883          82.17          248.00
#
# [62884 rows x 2 columns]

# %%
df
# Out:
#       StoreKey         StoreState   StoreCountry StoreOpenDate  \
# 0            5           Victoria      Australia    2015-12-09
# 1            4           Tasmania      Australia    2010-01-01
# 2            6  Western Australia      Australia    2010-01-01
# 3            6  Western Australia      Australia    2010-01-01
# 4            6  Western Australia      Australia    2010-01-01
# ...        ...                ...            ...           ...
# 62879       50             Kansas  United States    2008-03-06
# 62880       53            Montana  United States    2012-06-06
# 62881       53            Montana  United States    2012-06-06
# 62882       53            Montana  United States    2012-06-06
# 62883       53            Montana  United States    2012-06-06
#
#        StoreSurfaceAsSquareMeters Order Number  Order Date ProductKey  \
# 0                            2000      1520023  2019-02-28       1044
# 1                            2000      1120007  2018-01-24       2131
# 2                            2000       370013  2016-01-05          5
# 3                            2000       759002  2017-01-28          8
# 4                            2000       428009  2016-03-03        144
# ...                           ...          ...         ...        ...
# 62879                        2000      1715000  2019-09-11       1470
# 62880                        1260      1428025  2018-11-28       1644
# 62881                        1260      1428025  2018-11-28       2109
# 62882                        1260      1428025  2018-11-28       1621
# 62883                        1260      1428025  2018-11-28        721
#
#                                             Product Name              Brand  \
# 0                         A. Datum SLR Camera X135 Black           A. Datum
# 1               Contoso Coffee Maker Auto 5C E0900 White            Contoso
# 2                         Contoso 2G MP3 Player E200 Red            Contoso
# 3                      Contoso 4G MP3 Player E400 Silver            Contoso
# 4              Adventure Works 15.6 LCD TV M130W Brown""    Adventure Works
# ...                                                  ...                ...
# 62879  The Phone Company Smart phones without camera ...  The Phone Company
# 62880          Contoso DVD External DVD Burner M200 Blue            Contoso
# 62881             Contoso Water Heater 1.5GPM E0800 Grey            Contoso
# 62882                     Contoso DVD Movies E100 Yellow            Contoso
# 62883  Proseware High-Performance Business-Class Lase...          Proseware
#
#        ... Currency Code ExchangeVsUSD  Quantity  CustomerKey    Birthday  \
# 0      ...           AUD        1.4005         5         1585  1990-08-12
# 1      ...           AUD        1.2395         1         3203  1998-08-18
# 2      ...           AUD        1.3942         2         5097  1942-11-13
# 3      ...           AUD        1.3266         1        10299  1937-05-27
# 4      ...           AUD        1.3624         2        12160  1956-09-05
# ...    ...           ...           ...       ...          ...         ...
# 62879  ...           USD        1.0000         1      2051398  1979-04-15
# 62880  ...           USD        1.0000         6      2068819  1977-08-19
# 62881  ...           USD        1.0000         1      2068819  1977-08-19
# 62882  ...           USD        1.0000         4      2068819  1977-08-19
# 62883  ...           USD        1.0000        10      2068819  1977-08-19
#
#        Gender     CustomerCity    CustomerState CustomerCountry  \
# 0      Female       GREEN LAKE         Victoria       Australia
# 1        Male         ARGENTON  New South Wales       Australia
# 2      Female   Mount Pleasant       Queensland       Australia
# 3        Male      BEELBANGERA  New South Wales       Australia
# 4        Male         Oakhurst  New South Wales       Australia
# ...       ...              ...              ...             ...
# 62879    Male  Fort Washington     Pennsylvania   United States
# 62880  Female            Utica         New York   United States
# 62881  Female            Utica         New York   United States
# 62882  Female            Utica         New York   United States
# 62883  Female            Utica         New York   United States
#
#       CustomerContinent
# 0             Australia
# 1             Australia
# 2             Australia
# 3             Australia
# 4             Australia
# ...                 ...
# 62879     North America
# 62880     North America
# 62881     North America
# 62882     North America
# 62883     North America
#
# [62884 rows x 24 columns]

# %%
df.dtypes
# Out:
# StoreKey                       object
# StoreState                     object
# StoreCountry                   object
# StoreOpenDate                  object
# StoreSurfaceAsSquareMeters      int64
# Order Number                   object
# Order Date                     object
# ProductKey                     object
# Product Name                   object
# Brand                          object
# Category                       object
# Subcategory                    object
# Unit Cost USD                 float64
# Unit Price USD                float64
# Currency Code                  object
# ExchangeVsUSD                 float64
# Quantity                        int64
# CustomerKey                    object
# Birthday                       object
# Gender                         object
# CustomerCity                   object
# CustomerState                  object
# CustomerCountry                object
# CustomerContinent              object
# dtype: object

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Let's calculate the age of the customers by difference between the latest order date and their birthdate
max_date = max(df["Order Date"])
df['Age'] = df['Birthday'].apply(lambda x: int((max_date - x).days/365.25))
df['Age']
# Out:
# 0        30
# 1        22
# 2        78
# 3        83
# 4        64
#          ..
# 62879    41
# 62880    43
# 62881    43
# 62882    43
# 62883    43
# Name: Age, Length: 62884, dtype: int64

# %%
df["TotalSalesAmount"] = df["Unit Price USD"] * df["Quantity"]
df[["Unit Price USD", "Quantity", "TotalSalesAmount"]]
# Out:
#        Unit Price USD  Quantity  TotalSalesAmount
# 0              627.00         5           3135.00
# 1              163.00         1            163.00
# 2               21.57         2             43.14
# 3               59.99         1             59.99
# 4              299.99         2            599.98
# ...               ...       ...               ...
# 62879          129.00         1            129.00
# 62880           57.88         6            347.28
# 62881          257.50         1            257.50
# 62882           12.99         4             51.96
# 62883          248.00        10           2480.00
#
# [62884 rows x 3 columns]

# %% [markdown]
# ### Store analysis

# %% [markdown]
# sales / profitability store vs online
# sales / profitability by store country
# (sales / profitability by store state / key)

# %%
# Let's first calculate total cost
df["TotalCost"] = df["Unit Cost USD"] * df["Quantity"]
df[["Unit Cost USD", "Quantity", "TotalCost"]]
# Out:
#        Unit Cost USD  Quantity  TotalCost
# 0             207.74         5    1038.70
# 1              83.10         1      83.10
# 2              11.00         2      22.00
# 3              30.58         1      30.58
# 4             152.94         2     305.88
# ...              ...       ...        ...
# 62879          65.77         1      65.77
# 62880          26.62         6     159.72
# 62881         131.28         1     131.28
# 62882           6.62         4      26.48
# 62883          82.17        10     821.70
#
# [62884 rows x 3 columns]

# %%
# Now let's calculate profit
df["Profit"] = df["TotalSalesAmount"] - df["TotalCost"]
df[["TotalSalesAmount", "TotalCost", "Profit"]]
# Out:
#        TotalSalesAmount  TotalCost   Profit
# 0               3135.00    1038.70  2096.30
# 1                163.00      83.10    79.90
# 2                 43.14      22.00    21.14
# 3                 59.99      30.58    29.41
# 4                599.98     305.88   294.10
# ...                 ...        ...      ...
# 62879            129.00      65.77    63.23
# 62880            347.28     159.72   187.56
# 62881            257.50     131.28   126.22
# 62882             51.96      26.48    25.48
# 62883           2480.00     821.70  1658.30
#
# [62884 rows x 3 columns]

# %%
# And now we can calculate total profitability
df["TotalProfitability"] = df["Profit"] / df["TotalSalesAmount"]
df[["TotalSalesAmount", "Profit", "TotalProfitability"]]
# Out:
#        TotalSalesAmount   Profit  TotalProfitability
# 0               3135.00  2096.30            0.668676
# 1                163.00    79.90            0.490184
# 2                 43.14    21.14            0.490032
# 3                 59.99    29.41            0.490248
# 4                599.98   294.10            0.490183
# ...                 ...      ...                 ...
# 62879            129.00    63.23            0.490155
# 62880            347.28   187.56            0.540083
# 62881            257.50   126.22            0.490175
# 62882             51.96    25.48            0.490377
# 62883           2480.00  1658.30            0.668669
#
# [62884 rows x 3 columns]

# %%
# We also want to distinguish online vs in-store sales. A sale with a StoreKey value that is 0 is an online sale
df["StoreKey"].unique()
# Out:
# array(['5', '4', '6', '1', '0', '10', '9', '8', '27', '21', '23', '26',
#        '22', '20', '24', '19', '12', '13', '17', '16', '14', '18', '29',
#        '30', '28', '32', '31', '33', '34', '42', '39', '41', '37', '38',
#        '40', '36', '62', '45', '50', '56', '44', '59', '55', '51', '48',
#        '63', '43', '54', '57', '49', '47', '61', '64', '66', '53', '65',
#        '15', '2'], dtype=object)

# %%
# Let's count the number of sales by each storeKey
df["StoreKey"].value_counts()
# Out:
# StoreKey
# 0     13165
# 9      1577
# 50     1519
# 55     1518
# 54     1498
# 61     1485
# 59     1472
# 45     1471
# 57     1442
# 44     1436
# 65     1395
# 8      1360
# 51     1356
# 64     1353
# 47     1348
# 43     1340
# 66     1295
# 48     1289
# 56     1287
# 53     1284
# 10     1269
# 39     1054
# 40     1050
# 36     1049
# 49     1041
# 38     1034
# 42     1017
# 29     1011
# 37      995
# 30      976
# 63      948
# 5       892
# 22      800
# 62      778
# 27      721
# 24      703
# 23      674
# 19      635
# 6       615
# 33      498
# 32      454
# 34      448
# 41      444
# 20      443
# 4       431
# 31      417
# 21      391
# 26      295
# 1       292
# 15      235
# 12      224
# 16      214
# 28      214
# 17      210
# 18      194
# 13      184
# 14      126
# 2        18
# Name: count, dtype: int64

# %%
# To make the analysis easier, let's create a "Online / In-Store" column,
# indicating if this is an online or an In-Store sale
df["OnlineVsInstore"] = df["StoreKey"].apply(lambda x: "Online" if x=='0' else "In-Store")
df[["StoreKey", "OnlineVsInstore"]]
# Out:
#       StoreKey OnlineVsInstore
# 0            5        In-Store
# 1            4        In-Store
# 2            6        In-Store
# 3            6        In-Store
# 4            6        In-Store
# ...        ...             ...
# 62879       50        In-Store
# 62880       53        In-Store
# 62881       53        In-Store
# 62882       53        In-Store
# 62883       53        In-Store
#
# [62884 rows x 2 columns]

# %%
df.keys()
# Out:
# Index(['StoreKey', 'StoreState', 'StoreCountry', 'StoreOpenDate',
#        'StoreSurfaceAsSquareMeters', 'Order Number', 'Order Date',
#        'ProductKey', 'Product Name', 'Brand', 'Category', 'Subcategory',
#        'Unit Cost USD', 'Unit Price USD', 'Currency Code', 'ExchangeVsUSD',
#        'Quantity', 'CustomerKey', 'Birthday', 'Gender', 'CustomerCity',
#        'CustomerState', 'CustomerCountry', 'CustomerContinent', 'Age',
#        'TotalSalesAmount', 'TotalCost', 'Profit', 'TotalProfitability',
#        'OnlineVsInstore'],
#       dtype='object')

# %%
# Now we can make online vs in-store analysis, looking at the sales :
df.groupby("OnlineVsInstore")["TotalSalesAmount"].sum().reset_index()
# Out:
#   OnlineVsInstore  TotalSalesAmount
# 0        In-Store       44351154.96
# 1          Online       11404324.63

# %%
# and the corresponding pie chart :
px_pie_chart = px.pie(df, names = "OnlineVsInstore", title = "Online vs In-Store Sales")
px_pie_chart.show()
# Out:
# c:\Users\dimit\AppData\Local\Programs\Python\Python312\Lib\site-packages\plotly\express\_core.py:1871: FutureWarning:
#
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.

# %%
# Let's have a look at the sales per store :
sales_by_store_country = df.groupby("StoreCountry")["TotalSalesAmount"].sum().reset_index()
sales_by_store_country = sales_by_store_country.sort_values(by="TotalSalesAmount", ascending=False)
sales_by_store_country
# Out:
#      StoreCountry  TotalSalesAmount
# 8   United States       23764425.86
# 6          Online       11404324.63
# 7  United Kingdom        5749769.78
# 3         Germany        4246279.22
# 1          Canada        3611561.79
# 0       Australia        2099141.07
# 4           Italy        2059086.81
# 5     Netherlands        1591344.48
# 2          France        1229545.95

# %%
# and the corresponding horizontal bar chart :
fig = go.Figure(go.Bar(
            
# For a reason I ignore, I have to sort by ascending values of the TotalSalesAmount
# to have the bars by descending order of the TotalSalesAmount value
            x=sales_by_store_country["TotalSalesAmount"].sort_values(ascending=True),
            y=sales_by_store_country["StoreCountry"],
            orientation='h'))

fig.show()

# %%
# Let's have a look at the profits per store :
profitability_by_store_country = df.groupby("StoreCountry")["TotalProfitability"].mean().reset_index()
profitability_by_store_country = profitability_by_store_country.sort_values(by="TotalProfitability", ascending=False)
profitability_by_store_country
# Out:
#      StoreCountry  TotalProfitability
# 2          France            0.552046
# 0       Australia            0.551826
# 4           Italy            0.550946
# 5     Netherlands            0.550048
# 3         Germany            0.549935
# 8   United States            0.548829
# 7  United Kingdom            0.548577
# 6          Online            0.548499
# 1          Canada            0.547922

# %% [markdown]
# ### Orders & Sales analysis

# %% [markdown]
# Orders number by month and year
# Sales by month and year

# %%
print(df["Order Date"].min())
print(df["Order Date"].max())
# Out:
# 2016-01-01
# 2021-02-20

# %%
total_sales_per_date = df.groupby("Order Date")["TotalSalesAmount"].sum().reset_index()
total_sales_per_date
# Out:
#       Order Date  TotalSalesAmount
# 0     2016-01-01          37442.42
# 1     2016-01-02          91366.94
# 2     2016-01-03            362.64
# 3     2016-01-04           9524.94
# 4     2016-01-05          22996.38
# ...          ...               ...
# 1636  2021-02-16          27700.99
# 1637  2021-02-17          77408.70
# 1638  2021-02-18          35307.64
# 1639  2021-02-19          36476.44
# 1640  2021-02-20          61697.45
#
# [1641 rows x 2 columns]

# %%
total_sales_per_date["Year"] = total_sales_per_date["Order Date"].apply(lambda x : x.year)
total_sales_per_date["Month"] = total_sales_per_date["Order Date"].apply(lambda x : "Jan" if x.month == 1
                                                                                else "Feb" if x.month == 2
                                                                                else "Mar" if x.month == 3
                                                                                else "Apr" if x.month == 4
                                                                                else "May" if x.month == 5
                                                                                else "Jun" if x.month == 6
                                                                                else "Jul" if x.month == 7
                                                                                else "Aug" if x.month == 8
                                                                                else "Sep" if x.month == 9
                                                                                else "Oct" if x.month == 10
                                                                                else "Nov" if x.month == 11
                                                                                else "Dec")
total_sales_per_date["Month_Number"] = total_sales_per_date["Order Date"].apply(lambda x : x.month)
total_sales_per_date
# Out:
#       Order Date  TotalSalesAmount  Year Month  Month_Number
# 0     2016-01-01          37442.42  2016   Jan             1
# 1     2016-01-02          91366.94  2016   Jan             1
# 2     2016-01-03            362.64  2016   Jan             1
# 3     2016-01-04           9524.94  2016   Jan             1
# 4     2016-01-05          22996.38  2016   Jan             1
# ...          ...               ...   ...   ...           ...
# 1636  2021-02-16          27700.99  2021   Feb             2
# 1637  2021-02-17          77408.70  2021   Feb             2
# 1638  2021-02-18          35307.64  2021   Feb             2
# 1639  2021-02-19          36476.44  2021   Feb             2
# 1640  2021-02-20          61697.45  2021   Feb             2
#
# [1641 rows x 5 columns]

# %%
total_sales_per_date_aggregated = total_sales_per_date.groupby(["Year", "Month", "Month_Number"])["TotalSalesAmount"].sum().reset_index()
total_sales_per_date_aggregated = total_sales_per_date_aggregated.sort_values(by=["Year", "Month_Number"], ascending=True)
total_sales_per_date_aggregated
# Out:
#     Year Month  Month_Number  TotalSalesAmount
# 4   2016   Jan             1         649918.78
# 3   2016   Feb             2         891098.30
# 7   2016   Mar             3         338407.36
# 0   2016   Apr             4         110591.63
# 8   2016   May             5         595986.18
# ..   ...   ...           ...               ...
# 58  2020   Oct            10         245647.59
# 57  2020   Nov            11         256701.02
# 50  2020   Dec            12         651526.44
# 61  2021   Jan             1         513021.58
# 60  2021   Feb             2         526266.90
#
# [62 rows x 4 columns]

# %%
# Sales by month and year
fivelastyears_dropdown = go.Figure()

fivelastyears_dropdown.add_trace(
    go.Bar(
        x = total_sales_per_date_aggregated["Month"],
        y = total_sales_per_date_aggregated['TotalSalesAmount'].loc[total_sales_per_date_aggregated['Year'] == 2016],
        visible = True))

fivelastyears_dropdown.add_trace(
    go.Bar(
        x = total_sales_per_date_aggregated["Month"],
        y = total_sales_per_date_aggregated['TotalSalesAmount'].loc[total_sales_per_date_aggregated['Year'] == 2017],
        visible = False))

fivelastyears_dropdown.add_trace(
    go.Bar(
        x = total_sales_per_date_aggregated["Month"],
        y = total_sales_per_date_aggregated['TotalSalesAmount'].loc[total_sales_per_date_aggregated['Year'] == 2018],
        visible = False))

fivelastyears_dropdown.add_trace(
    go.Bar(
        x = total_sales_per_date_aggregated["Month"],
        y = total_sales_per_date_aggregated['TotalSalesAmount'].loc[total_sales_per_date_aggregated['Year'] == 2019],
        visible = False))

fivelastyears_dropdown.add_trace(
    go.Bar(
        x = total_sales_per_date_aggregated["Month"],
        y = total_sales_per_date_aggregated['TotalSalesAmount'].loc[total_sales_per_date_aggregated['Year'] == 2020],
        visible = False))

fivelastyears_dropdown.update_layout(
        title = go.layout.Title(text = "Sales per month per year 2016 - 2020", x = 0.5),
        showlegend = False)

fivelastyears_dropdown.update_layout(
    updatemenus = [go.layout.Updatemenu(
        active = 0,
        buttons = [
                    go.layout.updatemenu.Button(
                        label = "2016",
                        method = "update",
                        args = [{"visible" : [True, False, False, False, False]}]),
                    go.layout.updatemenu.Button(
                            label = "2017",
                            method = "update",
                            args = [{"visible" : [False, True, False, False, False]}]),
                    go.layout.updatemenu.Button(
                            label = "2018",
                            method = "update",
                            args = [{"visible" : [False, False, True, False, False]}]),
                    go.layout.updatemenu.Button(
                            label = "2019",
                            method = "update",
                            args = [{"visible" : [False, False, False, True, False]}]),
                    go.layout.updatemenu.Button(
                            label = "2020",
                            method = "update",
                            args = [{"visible" : [False, False, False, False, True]}]),
                ]
    )]
)

fivelastyears_dropdown.show()

# %%
# Orders by month and year
order_number_per_date = df.groupby("Order Date")["Order Number"].nunique().reset_index()
order_number_per_date
# Out:
#       Order Date  Order Number
# 0     2016-01-01            14
# 1     2016-01-02            30
# 2     2016-01-03             2
# 3     2016-01-04             9
# 4     2016-01-05            13
# ...          ...           ...
# 1636  2021-02-16            15
# 1637  2021-02-17            24
# 1638  2021-02-18            24
# 1639  2021-02-19            18
# 1640  2021-02-20            30
#
# [1641 rows x 2 columns]

# %%
order_number_per_date["Year"] = order_number_per_date["Order Date"].apply(lambda x : x.year)
order_number_per_date["Month"] = order_number_per_date["Order Date"].apply(lambda x : "Jan" if x.month == 1
                                                                                else "Feb" if x.month == 2
                                                                                else "Mar" if x.month == 3
                                                                                else "Apr" if x.month == 4
                                                                                else "May" if x.month == 5
                                                                                else "Jun" if x.month == 6
                                                                                else "Jul" if x.month == 7
                                                                                else "Aug" if x.month == 8
                                                                                else "Sep" if x.month == 9
                                                                                else "Oct" if x.month == 10
                                                                                else "Nov" if x.month == 11
                                                                                else "Dec")
order_number_per_date["Month_Number"] = order_number_per_date["Order Date"].apply(lambda x : x.month)
order_number_per_date
# Out:
#       Order Date  Order Number  Year Month  Month_Number
# 0     2016-01-01            14  2016   Jan             1
# 1     2016-01-02            30  2016   Jan             1
# 2     2016-01-03             2  2016   Jan             1
# 3     2016-01-04             9  2016   Jan             1
# 4     2016-01-05            13  2016   Jan             1
# ...          ...           ...   ...   ...           ...
# 1636  2021-02-16            15  2021   Feb             2
# 1637  2021-02-17            24  2021   Feb             2
# 1638  2021-02-18            24  2021   Feb             2
# 1639  2021-02-19            18  2021   Feb             2
# 1640  2021-02-20            30  2021   Feb             2
#
# [1641 rows x 5 columns]

# %%
order_number_per_date_aggregated = order_number_per_date.groupby(["Year", "Month", "Month_Number"])["Order Number"].sum().reset_index()
order_number_per_date_aggregated = order_number_per_date_aggregated.sort_values(by=["Year", "Month_Number"], ascending=True)
order_number_per_date_aggregated
# Out:
#     Year Month  Month_Number  Order Number
# 4   2016   Jan             1           292
# 3   2016   Feb             2           334
# 7   2016   Mar             3           109
# 0   2016   Apr             4            41
# 8   2016   May             5           220
# ..   ...   ...           ...           ...
# 58  2020   Oct            10           159
# 57  2020   Nov            11           149
# 50  2020   Dec            12           318
# 61  2021   Jan             1           256
# 60  2021   Feb             2           242
#
# [62 rows x 4 columns]

# %%
# Sales by month and year
fivelastyears_dropdown_orders = go.Figure()

fivelastyears_dropdown_orders.add_trace(
    go.Bar(
        x = order_number_per_date_aggregated["Month"],
        y = order_number_per_date_aggregated['Order Number'].loc[order_number_per_date_aggregated['Year'] == 2016],
        visible = True))

fivelastyears_dropdown_orders.add_trace(
    go.Bar(
        x = order_number_per_date_aggregated["Month"],
        y = order_number_per_date_aggregated['Order Number'].loc[order_number_per_date_aggregated['Year'] == 2017],
        visible = False))

fivelastyears_dropdown_orders.add_trace(
    go.Bar(
        x = order_number_per_date_aggregated["Month"],
        y = order_number_per_date_aggregated['Order Number'].loc[order_number_per_date_aggregated['Year'] == 2018],
        visible = False))

fivelastyears_dropdown_orders.add_trace(
    go.Bar(
        x = order_number_per_date_aggregated["Month"],
        y = order_number_per_date_aggregated['Order Number'].loc[order_number_per_date_aggregated['Year'] == 2019],
        visible = False))

fivelastyears_dropdown_orders.add_trace(
    go.Bar(
        x = order_number_per_date_aggregated["Month"],
        y = order_number_per_date_aggregated['Order Number'].loc[order_number_per_date_aggregated['Year'] == 2020],
        visible = False))

fivelastyears_dropdown_orders.update_layout(
        title = go.layout.Title(text = "Number of orders per month per year 2016 - 2020", x = 0.5),
        showlegend = False)

fivelastyears_dropdown_orders.update_layout(
    updatemenus = [go.layout.Updatemenu(
        active = 0,
        buttons = [
                    go.layout.updatemenu.Button(
                        label = "2016",
                        method = "update",
                        args = [{"visible" : [True, False, False, False, False]}]),
                    go.layout.updatemenu.Button(
                            label = "2017",
                            method = "update",
                            args = [{"visible" : [False, True, False, False, False]}]),
                    go.layout.updatemenu.Button(
                            label = "2018",
                            method = "update",
                            args = [{"visible" : [False, False, True, False, False]}]),
                    go.layout.updatemenu.Button(
                            label = "2019",
                            method = "update",
                            args = [{"visible" : [False, False, False, True, False]}]),
                    go.layout.updatemenu.Button(
                            label = "2020",
                            method = "update",
                            args = [{"visible" : [False, False, False, False, True]}]),
                ]
    )]
)

fivelastyears_dropdown_orders.show()

# %% [markdown]
# ### Products & Category analysis

# %% [markdown]
# Sales / profitability by category / subcategory / product with a dropdown
# Categories / subcategories / product bought together
# (optional : sales / profitability by brand ?)

# %% [markdown]
# ### Customer analysis

# %% [markdown]
# Sales by genre
# Sales by age
# Sales by country / state / city with a dropdown

# %%
df["CustomerCountry"].value_counts()
# Out:
# CustomerCountry
# United States     33767
# United Kingdom     8140
# Germany            5956
# Canada             5415
# Australia          2941
# Italy              2685
# Netherlands        2250
# France             1730
# Name: count, dtype: int64
